# %%
#  Import libraries

import pandas as pd
import numpy as np

# %%
s = pd.Series([3,4,2,np.nan,6,2,5,6,2])
s
# Out:
# 0    3.0
# 1    4.0
# 2    2.0
# 3    NaN
# 4    6.0
# 5    2.0
# 6    5.0
# 7    6.0
# 8    2.0
# dtype: float64

# %%
dates = pd.date_range('20001001',periods=12)
dates
# Out:
# DatetimeIndex(['2000-10-01', '2000-10-02', '2000-10-03', '2000-10-04',
#                '2000-10-05', '2000-10-06', '2000-10-07', '2000-10-08',
#                '2000-10-09', '2000-10-10', '2000-10-11', '2000-10-12'],
#               dtype='datetime64[ns]', freq='D')

# %%
df =pd.DataFrame(np.random.randn(12,3),index=dates, columns=list('ABC'))
df
# Out:
#                    A         B         C
# 2000-10-01  0.110738 -1.245779  0.510148
# 2000-10-02  0.395699  1.440926 -0.280575
# 2000-10-03 -1.343115 -1.977230  0.801594
# 2000-10-04 -2.060902  1.295034  0.318044
# 2000-10-05  1.759401  0.009491  0.448379
# 2000-10-06  2.043332  0.064519 -2.139280
# 2000-10-07 -0.706661  0.338263  0.643181
# 2000-10-08  1.679691  0.420446  0.679731
# 2000-10-09 -0.681835 -0.576232 -1.587717
# 2000-10-10  2.373689  2.764466  0.456080
# 2000-10-11 -0.444223 -1.184355 -0.855885
# 2000-10-12 -0.060229 -0.979817 -0.269323

# %%
d2 = pd.DataFrame(
{
  'A':'1.0',
  'B':pd.Timestamp(20220209),
  'D':pd.Series(1,index=list(range(4)),dtype="float32"),
  'C':np.array([3]*4,dtype="int32"),
  'E':pd.Categorical(["someone_1","someone_2","someone_3","someone_4",]),
  'F':"fool"
 }
)
d2
# Out:
#      A                             B    D  C          E     F
# 0  1.0 1970-01-01 00:00:00.020220209  1.0  3  someone_1  fool
# 1  1.0 1970-01-01 00:00:00.020220209  1.0  3  someone_2  fool
# 2  1.0 1970-01-01 00:00:00.020220209  1.0  3  someone_3  fool
# 3  1.0 1970-01-01 00:00:00.020220209  1.0  3  someone_4  fool

# %%
print(d2.dtypes)
# Out:
# A            object
# B    datetime64[ns]
# D           float32
# C             int32
# E          category
# F            object
# dtype: object

# %%
d2.index
# Out:
# Int64Index([0, 1, 2, 3], dtype='int64')

# %%
 d2.describe()
# Out:
#          D    C
# count  4.0  4.0
# mean   1.0  3.0
# std    0.0  0.0
# min    1.0  3.0
# 25%    1.0  3.0
# 50%    1.0  3.0
# 75%    1.0  3.0
# max    1.0  3.0

# %%
d2[0:]
# Out:
#      A                             B    D  C          E     F
# 0  1.0 1970-01-01 00:00:00.020220209  1.0  3  someone_1  fool
# 1  1.0 1970-01-01 00:00:00.020220209  1.0  3  someone_2  fool
# 2  1.0 1970-01-01 00:00:00.020220209  1.0  3  someone_3  fool
# 3  1.0 1970-01-01 00:00:00.020220209  1.0  3  someone_4  fool

# %%
d2[0:2]
# Out:
#      A                             B    D  C          E     F
# 0  1.0 1970-01-01 00:00:00.020220209  1.0  3  someone_1  fool
# 1  1.0 1970-01-01 00:00:00.020220209  1.0  3  someone_2  fool

# %%
d2.loc[:,["C","D"]]
# Out:
#    C    D
# 0  3  1.0
# 1  3  1.0
# 2  3  1.0
# 3  3  1.0

# %%
d2.loc['20220101':"20220104",["A","C"]]
# Out:
# Empty DataFrame
# Columns: [A, C]
# Index: []

# %%
d2.iloc[0:2,:]
# Out:
#      A                             B    D  C          E     F
# 0  1.0 1970-01-01 00:00:00.020220209  1.0  3  someone_1  fool
# 1  1.0 1970-01-01 00:00:00.020220209  1.0  3  someone_2  fool

# %%
d2.iloc[1:2,:3]
# Out:
#      A                             B    D
# 1  1.0 1970-01-01 00:00:00.020220209  1.0

# %%
df[df['C'] > 1]
# Out:
#                    A         B         C
# 2000-10-05 -1.416098  0.793983  1.045163
# 2000-10-10 -0.297103 -0.509514  1.479842

# %% [markdown]
# # Data Analysis of Titanoc dataset

# %%
#importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
k = sns.load_dataset('titanic')
k.head(4)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False

# %%
k.to_csv('titanic.csv')

# %%
k.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
k.head(3)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True

# %%
#  Dropping Few column for new dataset
k.drop(["deck","alone"],axis=1).head(4)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
#
#      who  adult_male  embark_town alive
# 0    man        True  Southampton    no
# 1  woman       False    Cherbourg   yes
# 2  woman       False  Southampton   yes
# 3  woman       False  Southampton   yes

# %%
k.mean()
# Out:
# C:\Users\NK107\AppData\Local\Temp/ipykernel_8144/3283639663.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   k.mean()
# survived       0.383838
# pclass         2.308642
# age           29.699118
# sibsp          0.523008
# parch          0.381594
# fare          32.204208
# adult_male     0.602694
# alone          0.602694
# dtype: float64

# %%
k.value_counts(["survived"])
# Out:
# survived
# 0           549
# 1           342
# dtype: int64

# %%
# adult related analysis

k.groupby(["sex","class"]).mean()
# Out:
#                survived  pclass        age     sibsp     parch        fare  \
# sex    class
# female First   0.968085     1.0  34.611765  0.553191  0.457447  106.125798
#        Second  0.921053     2.0  28.722973  0.486842  0.605263   21.970121
#        Third   0.500000     3.0  21.750000  0.895833  0.798611   16.118810
# male   First   0.368852     1.0  41.281386  0.311475  0.278689   67.226127
#        Second  0.157407     2.0  30.740707  0.342593  0.222222   19.741782
#        Third   0.135447     3.0  26.507589  0.498559  0.224784   12.661633
#
#                adult_male     alone
# sex    class
# female First     0.000000  0.361702
#        Second    0.000000  0.421053
#        Third     0.000000  0.416667
# male   First     0.975410  0.614754
#        Second    0.916667  0.666667
#        Third     0.919308  0.760807

# %%
k[k["age"] <  18].mean()
# Out:
# C:\Users\NK107\AppData\Local\Temp/ipykernel_8144/1331876749.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   k[k["age"] <  18].mean()
# survived       0.539823
# pclass         2.584071
# age            9.041327
# sibsp          1.460177
# parch          1.053097
# fare          31.220798
# adult_male     0.159292
# alone          0.203540
# dtype: float64

# %%
# Childrens related analysis

k[k["age"] <  18].groupby(["sex","class"]).mean()
# Out:
#                survived  pclass        age     sibsp     parch        fare  \
# sex    class
# female First   0.875000     1.0  14.125000  0.500000  0.875000  104.083337
#        Second  1.000000     2.0   8.333333  0.583333  1.083333   26.241667
#        Third   0.542857     3.0   8.428571  1.571429  1.057143   18.727977
# male   First   1.000000     1.0   8.230000  0.500000  2.000000  116.072900
#        Second  0.818182     2.0   4.757273  0.727273  1.000000   25.659473
#        Third   0.232558     3.0   9.963256  2.069767  1.000000   22.752523
#
#                adult_male     alone
# sex    class
# female First     0.000000  0.125000
#        Second    0.000000  0.166667
#        Third     0.000000  0.228571
# male   First     0.250000  0.000000
#        Second    0.181818  0.181818
#        Third     0.348837  0.232558
