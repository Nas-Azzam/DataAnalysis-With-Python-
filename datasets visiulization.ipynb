# %%
# import math
# w= 75000
def bmi():
 h=input('Enter your height : ')
 h = float(h)
 h = h * h
 w = input('Enter your weight : ')
 w = float(w)
 BMI  = w / h
 print(BMI)
b = bmi()
print( b   )
# Out:
# 8.333333333333334

# %%
# Data Visialization
# Categorical plot
import matplotlib.pyplot as plt

import seaborn as sns

sns.set_theme(style="ticks",color_codes=True)

titanic = sns.load_dataset("titanic")
p1 =sns.catplot(x="sex",y="survived",data=titanic,hue='class',kind='bar')
plt.show()
# p1 =sns.countplot(x="sex",data=titanic,hue='class')
# p1.set_title('plot for couting')
plt.show()

# %%
# Data Visialization
# Count Plot``
import matplotlib.pyplot as plt

import seaborn as sns

sns.set_theme(style="ticks",color_codes=True)

titanic = sns.load_dataset("titanic")
p1 =sns.countplot(x="sex",data=titanic,hue='class')
p1.set_title('plot for couting')
plt.show()

# %%
# Data Visialization
# Scatter Plot``
import matplotlib.pyplot as plt

import seaborn as sns

sns.set_theme(style="ticks",color_codes=True)

titanic = sns.load_dataset("titanic")
p1 =sns.FacetGrid(titanic,hue='alone',row='sex')

p1 = (p1.map(plt.scatter,'age','fare').add_legend())
plt.show()

# %%
# Againg dataVisulizaatiuon 
import seaborn as sns
import matplotlib.pyplot as plt


# dataSet Load
boat = sns.load_dataset("titanic")
# print(boat)
p = sns.countplot(x="sex",data=boat )
plt.show()
p1 = sns.countplot(x="sex",data=boat,hue='class' )
p1.set_title('title with plot')
plt.show()

# %%
# Imoirt Library
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
temp = sns.load_dataset('iris')
temp

# ploting Lines between attributes
plt.figure(figsize=(5,5))
t = sns.lineplot(x='sepal_width',y='petal_width',data=temp,hue='species')
plt.show()

# adding Title
plt.figure(figsize=(5,5))
t1 = sns.lineplot(x='sepal_width',y='petal_width',data=temp,hue='species')
plt.title('line Draw')
plt.show()

# Adding Styles
sns.set_theme(style="ticks",color_codes=True)
plt.figure(figsize=(5,5))
t1 = sns.lineplot(x='sepal_width',y='petal_width',data=temp,hue='species')
plt.title('line Draw')

sns.set_style(style='darkgrid')
# sns.set_style("darkgrid")
# plt.style.context("seaborn-dark")
plt.show()

# %%
# Imoirt Library
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
temp = sns.load_dataset('iris')
temp

# ploting BARPLOT between attributes
plt.figure(figsize=(5,5))
t = sns.barplot(x='species',y='petal_width',data=temp)
plt.title('BarDraw')
sns.set_style(style='darkgrid')
# sns.set_style("darkgrid")
# plt.style.context("seaborn-dark")
plt.show()

# %%
# Data Visulization
import matplotlib.pyplot as plt
import seaborn as sns

b = sns.load_dataset('titanic')
print(b.head())


plt.figure(figsize=(5,5))
sns.barplot(x='survived',y='fare',data=b,hue='sex',ci=None,palette='pastel',)
plt.show()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
#BOX plot 

import seaborn as sns
import numpy as np


b = sns.load_dataset('titanic')
# b.head()
# sns.boxenplot(x=)

# %%
import numpy as np
import seaborn as sns

d = sns.load_dataset('titanic')
d.head
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_3228/2465617753.py in <module>
#       1 import numpy as np
# ----> 2 import seaborn as sns
#       3
#       4 d = sns.load_dataset('titanic')
#       5 d.head
#
# ~\anaconda3\lib\site-packages\seaborn\__init__.py in <module>
#       1 # Import seaborn objects
# ----> 2 from .rcmod import *  # noqa: F401,F403
#       3 from .utils import *  # noqa: F401,F403
#       4 from .palettes import *  # noqa: F401,F403
#       5 from .relational import *  # noqa: F401,F403
#
# ~\anaconda3\lib\site-packages\seaborn\rcmod.py in <module>
#       5 import matplotlib as mpl
#       6 from cycler import cycler
# ----> 7 from . import palettes
#       8
#       9
#
# ~\anaconda3\lib\site-packages\seaborn\palettes.py in <module>
#       7 from .external import husl
#       8
# ...
